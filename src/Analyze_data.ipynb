# %%
# Import all necessary modules.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import *

import warnings
warnings.filterwarnings('ignore')

# %%
# read data
filename = "../data/train.csv"
traindata = pd.read_csv(filename)
traindata.set_index('id', inplace=True)

for a in range(1,117):
    a = "cat" + str(a)
    traindata[a] = traindata[a].astype('category')
    
filename = "../data/test.csv"
testdata = pd.read_csv(filename)
testdata.set_index('id', inplace=True)

for a in range(1,117):
    a = "cat" + str(a)
    testdata[a] = testdata[a].astype('category')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

traindata.head(4)
# Out:
#    cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10 cat11 cat12 cat13 cat14  \
# id
# 1     A    B    A    B    A    A    A    A    B     A     B     A     A     A
# 2     A    B    A    A    A    A    A    A    B     B     A     A     A     A
# 5     A    B    A    A    B    A    A    A    B     B     B     B     B     A
# 10    B    B    A    B    A    A    A    A    B     A     A     A     A     A
#
#    cat15 cat16 cat17 cat18 cat19 cat20 cat21 cat22 cat23 cat24 cat25 cat26  \
# id
# 1      A     A     A     A     A     A     A     A     B     A     A     A
# 2      A     A     A     A     A     A     A     A     A     A     A     A
# 5      A     A     A     A     A     A     A     A     A     A     A     A
# 10     A     A     A     A     A     A     A     A     B     A     A     A
#
#    cat27 cat28 cat29 cat30 cat31 cat32 cat33 cat34 cat35 cat36 cat37 cat38  \
# id
# 1      A     A     A     A     A     A     A     A     A     A     A     A
# ...

# %%
testdata.head(4)
# Out:
#    cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10 cat11 cat12 cat13 cat14  \
# id
# 4     A    B    A    A    A    A    A    A    B     A     B     A     A     A
# 6     A    B    A    B    A    A    A    A    B     A     A     A     A     A
# 9     A    B    A    B    B    A    B    A    B     B     A     B     B     B
# 12    A    A    A    A    B    A    A    A    A     A     A     A     A     A
#
#    cat15 cat16 cat17 cat18 cat19 cat20 cat21 cat22 cat23 cat24 cat25 cat26  \
# id
# 4      A     A     A     A     A     A     A     A     A     A     A     A
# 6      A     A     A     A     A     A     A     A     B     B     A     A
# 9      A     A     A     A     A     A     A     A     B     A     A     A
# 12     A     A     A     A     A     A     A     A     A     A     A     A
#
#    cat27 cat28 cat29 cat30 cat31 cat32 cat33 cat34 cat35 cat36 cat37 cat38  \
# id
# 4      A     A     A     A     A     A     A     A     A     A     A     A
# ...

# %%
traindata.dtypes
# Out:
# cat1      category
# cat2      category
# cat3      category
# cat4      category
# cat5      category
# cat6      category
# cat7      category
# cat8      category
# cat9      category
# cat10     category
# cat11     category
# cat12     category
# cat13     category
# cat14     category
# cat15     category
# cat16     category
# cat17     category
# cat18     category
# cat19     category
# cat20     category
# cat21     category
# cat22     category
# cat23     category
# cat24     category
# cat25     category
# cat26     category
# cat27     category
# cat28     category
# cat29     category
# cat30     category
# cat31     category
# cat32     category
# cat33     category
# cat34     category
# cat35     category
# cat36     category
# cat37     category
# cat38     category
# cat39     category
# cat40     category
# cat41     category
# cat42     category
# cat43     category
# cat44     category
# cat45     category
# cat46     category
# cat47     category
# ...

# %% [markdown]
# # 2. Summarize data

# %%
print traindata.shape
print testdata.shape
# Out:
# (188318, 131)
# (125546, 130)

# %%
traindata.describe(include=['number'])
# Out:
#                cont1          cont2          cont3          cont4  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.493861       0.507188       0.498918       0.491812
# std         0.187640       0.207202       0.202105       0.211292
# min         0.000016       0.001149       0.002634       0.176921
# 25%         0.346090       0.358319       0.336963       0.327354
# 50%         0.475784       0.555782       0.527991       0.452887
# 75%         0.623912       0.681761       0.634224       0.652072
# max         0.984975       0.862654       0.944251       0.954297
#
#                cont5          cont6          cont7          cont8  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.487428       0.490945       0.484970       0.486437
# std         0.209027       0.205273       0.178450       0.199370
# min         0.281143       0.012683       0.069503       0.236880
# ...

# %%
testdata.describe(include=['number'])
# Out:
#                cont1          cont2          cont3          cont4  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean        0.494447       0.506939       0.498255       0.492334
# std         0.187961       0.206837       0.201746       0.210815
# min         0.000016       0.001149       0.002634       0.176921
# 25%         0.347403       0.358319       0.336963       0.327354
# 50%         0.475784       0.555782       0.527991       0.452887
# 75%         0.626630       0.681761       0.634224       0.652072
# max         0.984975       0.862654       0.944251       0.956046
#
#                cont5          cont6          cont7          cont8  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean        0.487640       0.492188       0.485945       0.487401
# std         0.209119       0.205574       0.178650       0.199549
# min         0.281143       0.012683       0.069503       0.236880
# ...

# %%
traindata.describe(include=['object', 'category'])
# Out:
#           cat1    cat2    cat3    cat4    cat5    cat6    cat7    cat8  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    141550  106721  177993  128395  123737  131693  183744  177274
#
#           cat9   cat10   cat11   cat12   cat13   cat14   cat15   cat16  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    113122  160213  168186  159825  168851  186041  188284  181843
#
#          cat17   cat18   cat19   cat20   cat21   cat22   cat23   cat24  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# ...

# %%
testdata.describe(include=['object', 'category'])
# Out:
#           cat1    cat2    cat3    cat4    cat5    cat6    cat7    cat8  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq     94096   71203  118752   86026   82282   88014  122546  118112
#
#           cat9   cat10   cat11   cat12   cat13   cat14   cat15   cat16  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq     75509  106944  112470  106777  112604  123954  125523  121262
#
#          cat17   cat18   cat19   cat20   cat21   cat22   cat23   cat24  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# ...

# %% [markdown]
# I will encoding of categorical variables and remove some features not both in traindata and testdata.

# %%
categorial_cols = []
for num in range(1,117):
    cat = 'cat' + str(num)
    categorial_cols.append(cat)
# print categorial_cols

print "************ traindata ******************"
for categorial_col in categorial_cols:
    if (set(traindata[categorial_col].unique()) - set(testdata[categorial_col].unique())) != set():
        print categorial_col
        print set(traindata[categorial_col].unique()) - set(testdata[categorial_col].unique())

print "************ testdata ******************"
for categorial_col in categorial_cols:        
    if (set(testdata[categorial_col].unique()) - set(traindata[categorial_col].unique())) != set():
        print categorial_col
        print set(testdata[categorial_col].unique()) - set(traindata[categorial_col].unique())
# Out:
# ************ traindata ******************
# cat89
# set(['I'])
# cat90
# set(['G'])
# cat92
# set(['F'])
# cat101
# set(['U', 'N'])
# cat102
# set(['H', 'J'])
# cat105
# set(['S', 'R'])
# cat109
# set(['CJ', 'BF', 'B', 'AG', 'BM', 'AK', 'J', 'BT', 'BV', 'BP', 'BY'])
# cat110
# set(['BD', 'EI', 'EH', 'AF', 'H', 'BN', 'BI', 'BK', 'CB', 'DV', 'AN'])
# cat111
# set(['D'])
# cat113
# set(['BE', 'AC', 'T'])
# cat114
# set(['X'])
# cat116
# set(['BF', 'FS', 'IO', 'BL', 'BI', 'HU', 'JN', 'JO', 'JI', 'DY', 'JD', 'FN', 'FO', 'IB', 'JT', 'DQ', 'IX', 'C', 'AB', 'GQ', 'CC', 'AH', 'AM', 'AP', 'AS', 'AT', 'W', 'V', 'AY', 'X', 'EV', 'EQ', 'MF', 'MB', 'IK', 'MT', 'P', 'HO'])
# ************ testdata ******************
# cat89
# set(['F'])
# cat92
# set(['E', 'G'])
# cat96
# set(['H'])
# cat99
# set(['U'])
# cat103
# set(['M'])
# cat106
# set(['Q'])
# cat109
# set(['AD'])
# cat110
# set(['CA', 'EN', 'BH'])
# cat111
# set(['L'])
# cat113
# set(['AA', 'R'])
# cat116
# ...

# %%
################### remove train misssing data ##################################
traindata.loc[:,'cat89'] = traindata.loc[:,'cat89'].cat.remove_categories(['I'])
traindata.loc[:,'cat90'] = traindata.loc[:,'cat90'].cat.remove_categories(['G'])
traindata.loc[:,'cat92'] = traindata.loc[:,'cat92'].cat.remove_categories(['F'])
traindata.loc[:,'cat101'] = traindata.loc[:,'cat101'].cat.remove_categories(['U', 'N'])
traindata.loc[:,'cat102'] = traindata.loc[:,'cat102'].cat.remove_categories(['H', 'J'])
traindata.loc[:,'cat105'] = traindata.loc[:,'cat105'].cat.remove_categories(['S', 'R'])
traindata.loc[:,'cat109'] = traindata.loc[:,'cat109'].cat.remove_categories(['CJ', 'BF', 'B', 'AG', 'BM', 'AK', 'J', 'BT', 'BV', 'BP', 'BY'])
traindata.loc[:,'cat110'] = traindata.loc[:,'cat110'].cat.remove_categories(['BD', 'EI', 'EH', 'AF', 'H', 'BN', 'BI', 'BK', 'CB', 'DV', 'AN'])
traindata.loc[:,'cat111'] = traindata.loc[:,'cat111'].cat.remove_categories(['D'])
traindata.loc[:,'cat113'] = traindata.loc[:,'cat113'].cat.remove_categories(['BE', 'AC', 'T'])
traindata.loc[:,'cat114'] = traindata.loc[:,'cat114'].cat.remove_categories(['X'])
traindata.loc[:,'cat116'] = traindata.loc[:,'cat116'].cat.remove_categories(['BF', 'FS', 'IO', 'BL', 'BI', 'HU', 'JN', 'JO', 'JI', 'DY', 'JD', 
                                                                            'FN', 'FO', 'IB', 'JT', 'DQ', 'IX', 'C', 'AB', 'GQ', 'CC', 'AH', 
                                                                            'AM', 'AP', 'AS', 'AT', 'W', 'V', 'AY', 'X', 'EV', 'EQ', 'MF', 
                                                                            'MB', 'IK', 'MT', 'P', 'HO'])


################### remove test misssing data ##################################
testdata.loc[:,'cat89'] = testdata.loc[:,'cat89'].cat.remove_categories(['F'])
testdata.loc[:,'cat92'] = testdata.loc[:,'cat92'].cat.remove_categories(['E', 'G'])
testdata.loc[:,'cat96'] = testdata.loc[:,'cat96'].cat.remove_categories(['H'])
testdata.loc[:,'cat99'] = testdata.loc[:,'cat99'].cat.remove_categories(['U'])
testdata.loc[:,'cat103'] = testdata.loc[:,'cat103'].cat.remove_categories(['M'])
testdata.loc[:,'cat106'] = testdata.loc[:,'cat106'].cat.remove_categories(['Q'])
testdata.loc[:,'cat109'] = testdata.loc[:,'cat109'].cat.remove_categories(['AD'])
testdata.loc[:,'cat110'] = testdata.loc[:,'cat110'].cat.remove_categories(['CA', 'EN', 'BH'])
testdata.loc[:,'cat111'] = testdata.loc[:,'cat111'].cat.remove_categories(['L'])
testdata.loc[:,'cat113'] = testdata.loc[:,'cat113'].cat.remove_categories(['AA', 'R'])
testdata.loc[:,'cat116'] = testdata.loc[:,'cat116'].cat.remove_categories(['BE', 'HS', 'BN', 'BH', 'BJ', 'JS', 'BR', 'EM', 'LS', 'LP', 'FY',
                                                                           'A', 'AI', 'DB', 'IS', 'IW', 'N', 'AQ', 'EX', 'ET', 'ER', 'KO', 
                                                                           'MX'])

################### add train misssing data 'Other' categories #################
traindata.loc[:,'cat89'] = traindata.loc[:,'cat89'].cat.add_categories(['Others'])
traindata.loc[:,'cat90'] = traindata.loc[:,'cat90'].cat.add_categories(['Others'])
traindata.loc[:,'cat92'] = traindata.loc[:,'cat92'].cat.add_categories(['Others'])
traindata.loc[:,'cat101'] = traindata.loc[:,'cat101'].cat.add_categories(['Others'])
traindata.loc[:,'cat102'] = traindata.loc[:,'cat102'].cat.add_categories(['Others'])
traindata.loc[:,'cat105'] = traindata.loc[:,'cat105'].cat.add_categories(['Others'])
traindata.loc[:,'cat109'] = traindata.loc[:,'cat109'].cat.add_categories(['Others'])
traindata.loc[:,'cat110'] = traindata.loc[:,'cat110'].cat.add_categories(['Others'])
traindata.loc[:,'cat111'] = traindata.loc[:,'cat111'].cat.add_categories(['Others'])
traindata.loc[:,'cat113'] = traindata.loc[:,'cat113'].cat.add_categories(['Others'])
traindata.loc[:,'cat114'] = traindata.loc[:,'cat114'].cat.add_categories(['Others'])
traindata.loc[:,'cat116'] = traindata.loc[:,'cat116'].cat.add_categories(['Others'])


traindata.loc[:,'cat89'] = traindata.loc[:,'cat89'].fillna('Others')
traindata.loc[:,'cat90'] = traindata.loc[:,'cat90'].fillna('Others')
traindata.loc[:,'cat92'] = traindata.loc[:,'cat92'].fillna('Others')
traindata.loc[:,'cat101'] = traindata.loc[:,'cat101'].fillna('Others')
traindata.loc[:,'cat102'] = traindata.loc[:,'cat102'].fillna('Others')
traindata.loc[:,'cat105'] = traindata.loc[:,'cat105'].fillna('Others')
traindata.loc[:,'cat109'] = traindata.loc[:,'cat109'].fillna('Others')
traindata.loc[:,'cat110'] = traindata.loc[:,'cat110'].fillna('Others')
traindata.loc[:,'cat111'] = traindata.loc[:,'cat111'].fillna('Others')
traindata.loc[:,'cat113'] = traindata.loc[:,'cat113'].fillna('Others')
traindata.loc[:,'cat114'] = traindata.loc[:,'cat114'].fillna('Others')
traindata.loc[:,'cat116'] = traindata.loc[:,'cat116'].fillna('Others')

################### add test misssing data 'Other' categories ###################
testdata.loc[:,'cat89'] = testdata.loc[:,'cat89'].cat.add_categories(['Others'])
testdata.loc[:,'cat92'] = testdata.loc[:,'cat92'].cat.add_categories(['Others'])
testdata.loc[:,'cat96'] = testdata.loc[:,'cat96'].cat.add_categories(['Others'])
testdata.loc[:,'cat99'] = testdata.loc[:,'cat99'].cat.add_categories(['Others'])
testdata.loc[:,'cat103'] = testdata.loc[:,'cat103'].cat.add_categories(['Others'])
testdata.loc[:,'cat106'] = testdata.loc[:,'cat106'].cat.add_categories(['Others'])
testdata.loc[:,'cat109'] = testdata.loc[:,'cat109'].cat.add_categories(['Others'])
testdata.loc[:,'cat110'] = testdata.loc[:,'cat110'].cat.add_categories(['Others'])
testdata.loc[:,'cat111'] = testdata.loc[:,'cat111'].cat.add_categories(['Others'])
testdata.loc[:,'cat113'] = testdata.loc[:,'cat113'].cat.add_categories(['Others'])
testdata.loc[:,'cat116'] = testdata.loc[:,'cat116'].cat.add_categories(['Others'])

testdata.loc[:,'cat89'] = testdata.loc[:,'cat89'].fillna('Others')
testdata.loc[:,'cat92'] = testdata.loc[:,'cat92'].fillna('Others')
testdata.loc[:,'cat96'] = testdata.loc[:,'cat96'].fillna('Others')
testdata.loc[:,'cat99'] = testdata.loc[:,'cat99'].fillna('Others')
testdata.loc[:,'cat103'] = testdata.loc[:,'cat103'].fillna('Others')
testdata.loc[:,'cat106'] = testdata.loc[:,'cat106'].fillna('Others')
testdata.loc[:,'cat109'] = testdata.loc[:,'cat109'].fillna('Others')
testdata.loc[:,'cat110'] = testdata.loc[:,'cat110'].fillna('Others')
testdata.loc[:,'cat111'] = testdata.loc[:,'cat111'].fillna('Others')
testdata.loc[:,'cat113'] = testdata.loc[:,'cat113'].fillna('Others')
testdata.loc[:,'cat116'] = testdata.loc[:,'cat116'].fillna('Others')

# %%
traindata.describe(include=['object', 'category'])
# Out:
#           cat1    cat2    cat3    cat4    cat5    cat6    cat7    cat8  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    141550  106721  177993  128395  123737  131693  183744  177274
#
#           cat9   cat10   cat11   cat12   cat13   cat14   cat15   cat16  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    113122  160213  168186  159825  168851  186041  188284  181843
#
#          cat17   cat18   cat19   cat20   cat21   cat22   cat23   cat24  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# ...

# %% [markdown]
# # plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
contFeatureslist = []
for a in range(1,15):
    a = "cont" + str(a)
    contFeatureslist.append(a)

# %%
plt.figure(figsize=(13,9))
sns.boxplot(traindata[contFeatureslist])

# %%
plt.figure(figsize=(13,9))
sns.boxplot(testdata[contFeatureslist])

# %% [markdown]
# # Correlation between continuous features

# %%
correlationMatrix = testdata[contFeatureslist].corr().abs()

plt.subplots(figsize=(13, 9))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %%
contFeatureslist.append("loss")
correlationMatrix = traindata[contFeatureslist].corr().abs()

plt.subplots(figsize=(13, 9))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %% [markdown]
# # remove some features beacause of their correlation

# %%
contFeatureslist.remove("cont11")
correlationMatrix = traindata[contFeatureslist].corr().abs()

plt.subplots(figsize=(13, 9))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %%
contFeatureslist.remove("cont9")
correlationMatrix = traindata[contFeatureslist].corr().abs()

plt.subplots(figsize=(13, 9))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %%
contFeatureslist.remove("cont10")
correlationMatrix = traindata[contFeatureslist].corr().abs()

plt.subplots(figsize=(13, 9))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %%
contFeatureslist.remove("cont6")
correlationMatrix = traindata[contFeatureslist].corr().abs()

plt.subplots(figsize=(13, 9))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %%
contFeatureslist.remove("cont7")
correlationMatrix = traindata[contFeatureslist].corr().abs()

plt.subplots(figsize=(13, 9))
sns.heatmap(correlationMatrix,annot=True)

# Mask unimportant features
sns.heatmap(correlationMatrix, mask=correlationMatrix < 1, cbar=False)
plt.show()

# %% [markdown]
# I will remove cont6,cont7,cont9,cont10,cont11.

# %%
traindata = traindata.drop('cont6',1)
traindata = traindata.drop('cont7',1)
traindata = traindata.drop('cont9',1)
traindata = traindata.drop('cont10',1)
traindata = traindata.drop('cont11',1)

testdata = testdata.drop('cont6',1)
testdata = testdata.drop('cont7',1)
testdata = testdata.drop('cont9',1)
testdata = testdata.drop('cont10',1)
testdata = testdata.drop('cont11',1)

# %% [markdown]
# # save

# %%
traindata.to_csv('../data/train_drop.csv')
testdata.to_csv('../data/test_drop.csv')

# %%
print traindata.shape
print testdata.shape
# Out:
# (188318, 126)
# (125546, 125)
